# %%
# !pip install ultralytics
# Out:
# ...
#   Using cached ultralytics-8.4.41-py3-none-any.whl.metadata (39 kB)
# ...
#   Using cached numpy-2.4.4-cp313-cp313-win_amd64.whl.metadata (6.6 kB)
# ...
#   Using cached matplotlib-3.10.9-cp313-cp313-win_amd64.whl.metadata (52 kB)
# ...
#   Using cached opencv_python-4.13.0.92-cp37-abi3-win_amd64.whl.metadata (20 kB)
# ...
#   Using cached pillow-12.2.0-cp313-cp313-win_amd64.whl.metadata (9.0 kB)
# ...
#   Using cached pyyaml-6.0.3-cp313-cp313-win_amd64.whl.metadata (2.4 kB)
# ...
#   Using cached requests-2.33.1-py3-none-any.whl.metadata (4.8 kB)
# ...
#   Using cached scipy-1.17.1-cp313-cp313-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached torch-2.11.0-cp313-cp313-win_amd64.whl.metadata (29 kB)
# ...
#   Using cached torchvision-0.26.0-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# ...
#   Using cached polars-1.40.1-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached ultralytics_thop-2.0.19-py3-none-any.whl.metadata (14 kB)
# ...
#   Using cached contourpy-1.3.3-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="w0WrrKHoEIjB5SqpNv2E")
project = rf.workspace("sami-semir").project("my-first-project-q8ldn")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# [notice] A new release of pip is available: 24.2 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.3/38.8 MB ? eta -:--:--
#    - -------------------------------------- 1.3/38.8 MB 3.6 MB/s eta 0:00:11
#    --- ------------------------------------ 3.1/38.8 MB 5.8 MB/s eta 0:00:07
#    ----- ---------------------------------- 5.0/38.8 MB 6.7 MB/s eta 0:00:06
#    ------- -------------------------------- 7.1/38.8 MB 7.4 MB/s eta 0:00:05
#    --------- ------------------------------ 9.2/38.8 MB 7.9 MB/s eta 0:00:04
#    ----------- ---------------------------- 11.5/38.8 MB 8.3 MB/s eta 0:00:04
#    -------------- ------------------------- 13.6/38.8 MB 8.5 MB/s eta 0:00:03
#    ---------------- ----------------------- 15.7/38.8 MB 8.6 MB/s eta 0:00:03
#    ----------------- ---------------------- 17.0/38.8 MB 8.7 MB/s eta 0:00:03
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="My-First-Project-2/data.yaml",
    epochs=30,
    imgsz=640,
    name="final_run"
)
# Out:
# ...
# Ultralytics 8.4.41  Python-3.13.0 torch-2.11.0+cpu CPU (12th Gen Intel Core i7-1250U)
# ...

# %%
from ultralytics import YOLO

model = YOLO("runs/detect/final_run/weights/best.pt")

model("test.jpg", save=True)
# Out:
# image 1/1 c:\Users\Sami\Desktop\UNI\Applied Artificial Intelligence\smart-device-detection\smart-device-detection\test.jpg: 384x640 1 laptop, 138.8ms
# Speed: 36.8ms preprocess, 138.8ms inference, 13.4ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to C:\Users\Sami\Desktop\UNI\Applied Artificial Intelligence\smart-device-detection\smart-device-detection\runs\detect\predict
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'laptop', 1: 'monitor', 2: 'phone'}
#  obb: None
#  orig_img: array([[[120,  76,  83],
#          [120,  76,  83],
#          [121,  77,  84],
#          ...,
#          [132,  63,  84],
#          [130,  64,  83],
#          [129,  63,  82]],
#
#         [[120,  76,  83],
#          [120,  76,  83],
#          [121,  77,  84],
#          ...,
#          [132,  63,  84],
#          [130,  64,  83],
#          [130,  64,  83]],
#
# ...

# %%
from ultralytics import YOLO

model = YOLO("runs/detect/final_run/weights/best.pt")

model("test2.jpg", save=True)
# Out:
# image 1/1 c:\Users\Sami\Desktop\UNI\Applied Artificial Intelligence\smart-device-detection\smart-device-detection\test2.jpg: 640x640 1 monitor, 266.9ms
# Speed: 46.6ms preprocess, 266.9ms inference, 31.6ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to C:\Users\Sami\Desktop\UNI\Applied Artificial Intelligence\smart-device-detection\smart-device-detection\runs\detect\predict-5
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'laptop', 1: 'monitor', 2: 'phone'}
#  obb: None
#  orig_img: array([[[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
# ...

# %%
from ultralytics import YOLO

model = YOLO("runs/detect/final_run/weights/best.pt")

model("test3.jpg", save=True)
# Out:
# image 1/1 c:\Users\Sami\Desktop\UNI\Applied Artificial Intelligence\smart-device-detection\smart-device-detection\test3.jpg: 512x640 1 phone, 224.1ms
# Speed: 28.2ms preprocess, 224.1ms inference, 28.1ms postprocess per image at shape (1, 3, 512, 640)
# Results saved to C:\Users\Sami\Desktop\UNI\Applied Artificial Intelligence\smart-device-detection\smart-device-detection\runs\detect\predict-3
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'laptop', 1: 'monitor', 2: 'phone'}
#  obb: None
#  orig_img: array([[[100, 137, 171],
#          [102, 139, 173],
#          [101, 136, 170],
#          ...,
#          [ 10,  15,  18],
#          [ 19,  25,  30],
#          [ 36,  45,  54]],
#
#         [[ 99, 136, 170],
#          [101, 138, 172],
#          [100, 135, 169],
#          ...,
#          [ 10,  15,  18],
#          [ 20,  26,  31],
#          [ 36,  45,  54]],
#
# ...
